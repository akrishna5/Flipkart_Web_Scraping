# %%
# pip install pandas
# pip install requests
# pip install beautifulsoup4

import pandas as pd
import requests
from bs4 import BeautifulSoup

# %%
# HTTPS Response Code

url = "https://www.flipkart.com"
r = requests.get(url)
print(r)
# Out:
# <Response [200]>

# %% [markdown]
# #### Search - "mobiles under 50000"
# #### Result - No. of pages = 412

# %%
# HTML data for Page-1 only
# Check data in text editor - find "8 GB" - Line No. 24

url = "https://www.flipkart.com/search?q=mobiles+under+50000&as=on&as-show=on&otracker=AS_Query_OrganicAutoSuggest_2_16_na_na_ps&otracker1=AS_Query_OrganicAutoSuggest_2_16_na_na_ps&as-pos=2&as-type=RECENT&suggestionId=mobiles+under+50000&requestId=fc39be41-5ae0-4280-94d9-0ae85ebb272f&as-searchtext=mobiles+under+50000&page=1"
r = requests.get(url)
soup = BeautifulSoup(r.text, "lxml")
print(soup)
# Out:
# <!DOCTYPE html>
# ...

# %%
# Link for next pages using Anchor Tag <a> of Next Button
# Link in the result is without the hostname "www.flipkart.com"

np = soup.find("a", class_ = "_9QVEpD").get("href")
print(np)
# Out:
# /search?q=mobiles+under+50000&as=on&as-show=on&otracker=AS_Query_OrganicAutoSuggest_2_16_na_na_ps&otracker1=AS_Query_OrganicAutoSuggest_2_16_na_na_ps&as-pos=2&as-type=RECENT&suggestionId=mobiles+under+50000&requestId=fc39be41-5ae0-4280-94d9-0ae85ebb272f&as-searchtext=mobiles+under+50000&page=2

# %%
# Add the hostname in the link
# Link for Page-2

cnp = "https://www.flipkart.com"+np
print(cnp)
# Out:
# https://www.flipkart.com/search?q=mobiles+under+50000&as=on&as-show=on&otracker=AS_Query_OrganicAutoSuggest_2_16_na_na_ps&otracker1=AS_Query_OrganicAutoSuggest_2_16_na_na_ps&as-pos=2&as-type=RECENT&suggestionId=mobiles+under+50000&requestId=fc39be41-5ae0-4280-94d9-0ae85ebb272f&as-searchtext=mobiles+under+50000&page=2

# %%
# Loop for Links of Page No. 1-8

for i in range(2,10):
    url = "https://www.flipkart.com/search?q=mobiles+under+50000&as=on&as-show=on&otracker=AS_Query_OrganicAutoSuggest_2_16_na_na_ps&otracker1=AS_Query_OrganicAutoSuggest_2_16_na_na_ps&as-pos=2&as-type=RECENT&suggestionId=mobiles+under+50000&requestId=fc39be41-5ae0-4280-94d9-0ae85ebb272f&as-searchtext=mobiles+under+50000&page="+str(i)
    r = requests.get(url)
    soup = BeautifulSoup(r.text, "lxml")
    
    # Next Page
    np = soup.find("a", class_ = "_9QVEpD").get("href")
    cnp = "https://www.flipkart.com"+np
    print(cnp)
# Out:
# https://www.flipkart.com/search?q=mobiles+under+50000&as=on&as-show=on&otracker=AS_Query_OrganicAutoSuggest_2_16_na_na_ps&otracker1=AS_Query_OrganicAutoSuggest_2_16_na_na_ps&as-pos=2&as-type=RECENT&suggestionId=mobiles+under+50000&requestId=fc39be41-5ae0-4280-94d9-0ae85ebb272f&as-searchtext=mobiles+under+50000&page=1
# https://www.flipkart.com/search?q=mobiles+under+50000&as=on&as-show=on&otracker=AS_Query_OrganicAutoSuggest_2_16_na_na_ps&otracker1=AS_Query_OrganicAutoSuggest_2_16_na_na_ps&as-pos=2&as-type=RECENT&suggestionId=mobiles+under+50000&requestId=fc39be41-5ae0-4280-94d9-0ae85ebb272f&as-searchtext=mobiles+under+50000&page=2
# https://www.flipkart.com/search?q=mobiles+under+50000&as=on&as-show=on&otracker=AS_Query_OrganicAutoSuggest_2_16_na_na_ps&otracker1=AS_Query_OrganicAutoSuggest_2_16_na_na_ps&as-pos=2&as-type=RECENT&suggestionId=mobiles+under+50000&requestId=fc39be41-5ae0-4280-94d9-0ae85ebb272f&as-searchtext=mobiles+under+50000&page=3
# ...

# %%
# Data Reading of Page-1
# GET - Product Name, Reviews, Prices, Description

Product_name = []
Prices = []
Description = []
Reviews = []

url = "https://www.flipkart.com/search?q=mobiles+under+50000&as=on&as-show=on&otracker=AS_Query_OrganicAutoSuggest_2_16_na_na_ps&otracker1=AS_Query_OrganicAutoSuggest_2_16_na_na_ps&as-pos=2&as-type=RECENT&suggestionId=mobiles+under+50000&requestId=fc39be41-5ae0-4280-94d9-0ae85ebb272f&as-searchtext=mobiles+under+50000&page="+str(1)
r = requests.get(url)
soup = BeautifulSoup(r.text, "lxml")
print(soup)
# Out:
# <!DOCTYPE html>
# ...

# %%
names = soup.find_all("div", class_ = "KzDlHZ")
print(names)
# Out:
# [<div class="KzDlHZ">SAMSUNG Galaxy S23 5G (Phantom Black, 128 GB)</div>, <div class="KzDlHZ">SAMSUNG Galaxy S23 5G (Lavender, 128 GB)</div>, <div class="KzDlHZ">SAMSUNG Galaxy S23 5G (Green, 128 GB)</div>, <div class="KzDlHZ">SAMSUNG Galaxy S23 FE (Purple, 128 GB)</div>, <div class="KzDlHZ">OnePlus 11R 5G (Sonic Black, 256 GB)</div>, <div class="KzDlHZ">SAMSUNG Galaxy S23 FE (Graphite, 256 GB)</div>, <div class="KzDlHZ">SAMSUNG Galaxy S23 5G (Cream, 128 GB)</div>, <div class="KzDlHZ">OnePlus 12R (Cool Blue, 256 GB)</div>, <div class="KzDlHZ">Nothing Phone (2) (White, 512 GB)</div>, <div class="KzDlHZ">vivo V30 Pro 5G (Classic Black, 512 GB)</div>, <div class="KzDlHZ">vivo V30 Pro 5G (Andaman Blue, 512 GB)</div>, <div class="KzDlHZ">Google Pixel 7 (Obsidian, 128 GB)</div>, <div class="KzDlHZ">Apple iPhone 11 (Green, 128 GB)</div>, <div class="KzDlHZ">Google Pixel 7 (Lemongrass, 128 GB)</div>, <div class="KzDlHZ">Google Pixel 7 (Snow, 128 GB)</div>, <div class="KzDlHZ">Apple iPhone 6 
# ...

# %%
# Print all the products in a list

names = soup.find_all("div", class_ = "KzDlHZ")

for i in names:
    name = i.text
    Product_name.append(name)
print(Product_name)
# Out:
# ['SAMSUNG Galaxy S23 5G (Phantom Black, 128 GB)', 'SAMSUNG Galaxy S23 5G (Lavender, 128 GB)', 'SAMSUNG Galaxy S23 5G (Green, 128 GB)', 'SAMSUNG Galaxy S23 FE (Purple, 128 GB)', 'OnePlus 11R 5G (Sonic Black, 256 GB)', 'SAMSUNG Galaxy S23 FE (Graphite, 256 GB)', 'SAMSUNG Galaxy S23 5G (Cream, 128 GB)', 'OnePlus 12R (Cool Blue, 256 GB)', 'Nothing Phone (2) (White, 512 GB)', 'vivo V30 Pro 5G (Classic Black, 512 GB)', 'vivo V30 Pro 5G (Andaman Blue, 512 GB)', 'Google Pixel 7 (Obsidian, 128 GB)', 'Apple iPhone 11 (Green, 128 GB)', 'Google Pixel 7 (Lemongrass, 128 GB)', 'Google Pixel 7 (Snow, 128 GB)', 'Apple iPhone 6 Plus (Silver, 64 GB)', 'Apple iPhone 11 (White, 64 GB) (Includes EarPods, Power Adapter)', 'OPPO Reno10 Pro+ 5G (Silvery Grey, 256 GB)', 'SAMSUNG Galaxy A55 5G (Awesome Navy, 256 GB)', 'Apple iPhone 11 (Purple, 128 GB)', 'Mi 10T Pro (Cosmic Black, 128 GB)', 'OnePlus 10 Pro 5G (Emerald Forest, 128 GB)', 'SAMSUNG Galaxy A55 5G (Awesome Iceblue, 256 GB)', 'OnePlus 11 5G (Titan Bl
# ...

# %%
print(len(Product_name))
# Out:
# 24

# %% [markdown]
# ### For Single Page:
# ### Data Analysis - Dataframe

# %%
Product_name = []
Prices = []
Description = []
Rating = []

url = "https://www.flipkart.com/search?q=mobiles+under+50000&as=on&as-show=on&otracker=AS_Query_OrganicAutoSuggest_2_16_na_na_ps&otracker1=AS_Query_OrganicAutoSuggest_2_16_na_na_ps&as-pos=2&as-type=RECENT&suggestionId=mobiles+under+50000&requestId=fc39be41-5ae0-4280-94d9-0ae85ebb272f&as-searchtext=mobiles+under+50000&page="+str(1)
r = requests.get(url)
soup = BeautifulSoup(r.text, "lxml")
box = soup.find("div", class_ = "DOjaWF gdgoEp")

names = box.find_all("div", class_ = "KzDlHZ")
for i in names:
    name = i.text
    Product_name.append(name)
print(Product_name)
print(len(Product_name))

prices = box.find_all("div", class_ = "Nx9bqj _4b5DiR")
for i in prices:
    name = i.text
    Prices.append(name)
print(Prices)
print(len(Prices))

desc = box.find_all("ul", class_ = "G4BRas")
for i in desc:
    name = i.text
    Description.append(name)
print(Description)
print(len(Description))

rating = box.find_all("div", class_ = "XQDdHH")
for i in rating:
    name = i.text
    Rating.append(name)
print(Rating)
print(len(Rating))

df1 = pd.DataFrame({"Product Name": Product_name,
                   "Prices": Prices,
                   "Description": Description,
                   "Rating": Rating})
print(df1)
# Out:
# ['SAMSUNG Galaxy S23 5G (Phantom Black, 128 GB)', 'SAMSUNG Galaxy S23 5G (Lavender, 128 GB)', 'SAMSUNG Galaxy S23 5G (Green, 128 GB)', 'SAMSUNG Galaxy S23 FE (Purple, 128 GB)', 'OnePlus 11R 5G (Sonic Black, 256 GB)', 'SAMSUNG Galaxy S23 FE (Graphite, 256 GB)', 'SAMSUNG Galaxy S23 5G (Cream, 128 GB)', 'OnePlus 12R (Cool Blue, 256 GB)', 'Nothing Phone (2) (White, 512 GB)', 'vivo V30 Pro 5G (Andaman Blue, 512 GB)', 'vivo V30 Pro 5G (Classic Black, 512 GB)', 'Google Pixel 7 (Obsidian, 128 GB)', 'Apple iPhone 11 (Green, 128 GB)', 'Google Pixel 7 (Lemongrass, 128 GB)', 'Google Pixel 7 (Snow, 128 GB)', 'Apple iPhone 6 Plus (Silver, 64 GB)', 'OPPO Reno10 Pro+ 5G (Silvery Grey, 256 GB)', 'Apple iPhone 11 (White, 64 GB) (Includes EarPods, Power Adapter)', 'SAMSUNG Galaxy A55 5G (Awesome Navy, 256 GB)', 'Apple iPhone 11 (Purple, 128 GB)', 'Mi 10T Pro (Cosmic Black, 128 GB)', 'OnePlus 10 Pro 5G (Emerald Forest, 128 GB)', 'SAMSUNG Galaxy A55 5G (Awesome Iceblue, 256 GB)', 'OnePlus 11 5G (Titan Bl
# ...

# %% [markdown]
# ### For Multiple Pages:
# ### Data Analysis - Dataframe

# %%
Product_name = []
Prices = []
Description = []
Rating = []

for i in range(1,6):
    url = "https://www.flipkart.com/search?q=mobiles+under+50000&as=on&as-show=on&otracker=AS_Query_OrganicAutoSuggest_2_16_na_na_ps&otracker1=AS_Query_OrganicAutoSuggest_2_16_na_na_ps&as-pos=2&as-type=RECENT&suggestionId=mobiles+under+50000&requestId=fc39be41-5ae0-4280-94d9-0ae85ebb272f&as-searchtext=mobiles+under+50000&page="+str(i)
    r = requests.get(url)
    soup = BeautifulSoup(r.text, "lxml")
    box = soup.find("div", class_ = "DOjaWF gdgoEp")

    names = box.find_all("div", class_ = "KzDlHZ")
    for i in names:
        name = i.text
        Product_name.append(name)

    prices = box.find_all("div", class_ = "Nx9bqj _4b5DiR")
    for i in prices:
        name = i.text
        Prices.append(name)

    desc = box.find_all("ul", class_ = "G4BRas")
    for i in desc:
        name = i.text
        Description.append(name)

    rating = box.find_all("div", class_ = "XQDdHH")
    for i in rating:
        name = i.text
        Rating.append(name)

df = pd.DataFrame({"Product Name": Product_name,
                   "Prices": Prices,
                   "Description": Description,
                   "Rating": Rating})
print(df)
# Out:
#                                       Product Name   Prices  \
# 0    SAMSUNG Galaxy S23 5G (Phantom Black, 128 GB)  ₹49,999
# 1         SAMSUNG Galaxy S23 5G (Lavender, 128 GB)  ₹49,999
# 2            SAMSUNG Galaxy S23 5G (Green, 128 GB)  ₹49,999
# 3           SAMSUNG Galaxy S23 FE (Purple, 128 GB)  ₹39,999
# 4             OnePlus 11R 5G (Sonic Black, 256 GB)  ₹35,739
# ..                                             ...      ...
# 115                 Apple iPhone 12 (Black, 64 GB)  ₹39,999
# 116                  Google Pixel 7a (Sea, 128 GB)  ₹39,999
# 117             vivo V30 5G (Andaman Blue, 256 GB)  ₹35,999
# 118  REDMI Note 13 Pro+ 5G (Fusion Purple, 512 GB)  ₹32,999
# 119                     IQOO 9T 5G (ALPHA, 128 GB)  ₹45,799
#
#                                            Description Rating
# 0    8 GB RAM | 128 GB ROM15.49 cm (6.1 inch) Full ...    4.6
# 1    8 GB RAM | 128 GB ROM15.49 cm (6.1 inch) Full ...    4.6
# ...

# %% [markdown]
# ### Dataframe To Excel (CSV)

# %%
df.to_csv("flipkart_mobiles_under_50000.csv")
